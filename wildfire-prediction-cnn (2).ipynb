# %%
# if you use gpu accelerator in kaggle
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## 1. Importing Libraries

# %%
import tensorflow as tf

from tensorflow.keras import optimizers, regularizers
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import numpy as np
import matplotlib.pyplot as plt

import cv2
import os
import pandas as pd

# %%
for device in tf.config.list_physical_devices():
    print(": {}".format(device.name))
# Out:
# : /physical_device:CPU:0
# : /physical_device:GPU:0

# %% [markdown]
# ## 2. Gathering Data

# %%
# defining paths of train, validation and test data
train_path = "../input/wildfire-prediction-dataset/train"
valid_path = "../input/wildfire-prediction-dataset/valid"
test_path = "../input/wildfire-prediction-dataset/test"

# %%
image_shape = (350,350,3)
N_CLASSES = 2
BATCH_SIZE = 256

# loading training data and rescaling it using ImageDataGenerator
train_datagen = ImageDataGenerator(dtype='float32', rescale= 1./255.)
train_generator = train_datagen.flow_from_directory(train_path,
                                                   batch_size = BATCH_SIZE,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')

# loading validation data and rescaling it using ImageDataGenerator
valid_datagen = ImageDataGenerator(dtype='float32', rescale= 1./255.)
valid_generator = valid_datagen.flow_from_directory(valid_path,
                                                   batch_size = BATCH_SIZE,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')

# loading test data and rescaling it using ImageDataGenerator
test_datagen = ImageDataGenerator(dtype='float32', rescale = 1.0/255.0)
test_generator = test_datagen.flow_from_directory(test_path,
                                                   batch_size = BATCH_SIZE,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
# Out:
# Found 30250 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.
# Found 6300 images belonging to 2 classes.

# %% [markdown]
# ## 3. Building the model

# %%
# defining the coefficient that our regularizer will use
weight_decay = 1e-3

# building a sequential CNN model and adding layers to it
# dropout and the regularizer are used in general to prevent overfitting
first_model = Sequential([
    Conv2D(filters = 8 , kernel_size = 2, activation = 'relu', 
    input_shape = image_shape), MaxPooling2D(pool_size = 2),
    
    Conv2D(filters = 16 , kernel_size = 2, activation = 'relu', 
    input_shape = image_shape), MaxPooling2D(pool_size = 2),
    
    Conv2D(filters = 32 , kernel_size = 2, activation = 'relu',
           kernel_regularizer = regularizers.l2(weight_decay)),
    MaxPooling2D(pool_size = 2),
    
    Dropout(0.4),
    Flatten(),
    Dense(300,activation='relu'),
    Dropout(0.5),
    Dense(2,activation='softmax')
])
# showing the summary of our model (layers and number of parameters)
first_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 349, 349, 8)       104
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 174, 174, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 173, 173, 16)      528
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 86, 86, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 42, 42, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 42, 42, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 56448)             0
# _________________________________________________________________
# dense (Dense)                (None, 300)               16934700
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 16,938,014
# Trainable params: 16,938,014
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4. Training the model

# %%
# don't stop everything if an image didn't load correctly
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# checkpointer to save the model only if it improved
checkpointer = ModelCheckpoint('first_model.hdf5',verbose=1, save_best_only= True)
# early stopping to stop the training if our validation loss didn't decrease for (10) consecutive epochs
early_stopping = EarlyStopping(monitor= 'val_loss', patience= 10)
# Adam, best optimiser for deep learning models to help with the training
optimizer = optimizers.Adam(learning_rate= 0.00001, decay= 1e-5)
# setting our loss function and which metric to evaluate
first_model.compile(loss= 'categorical_crossentropy', optimizer= optimizer,
                    metrics=['AUC','acc'])

# TRAIN
history = first_model.fit(train_generator,
                    epochs = 50,
                    verbose = 1,
                    validation_data = valid_generator,
                    callbacks = [checkpointer, early_stopping])
# Out:
# Epoch 1/50
# 119/119 [==============================] - 341s 3s/step - loss: 0.6599 - auc: 0.6735 - acc: 0.5938 - val_loss: 0.5619 - val_auc: 0.8529 - val_acc: 0.7595
#
# Epoch 00001: val_loss improved from inf to 0.56190, saving model to first_model.hdf5
# Epoch 2/50
# 119/119 [==============================] - 241s 2s/step - loss: 0.4874 - auc: 0.8889 - acc: 0.8120 - val_loss: 0.3920 - val_auc: 0.9356 - val_acc: 0.8646
#
# Epoch 00002: val_loss improved from 0.56190 to 0.39204, saving model to first_model.hdf5
# Epoch 3/50
# 119/119 [==============================] - 240s 2s/step - loss: 0.3747 - auc: 0.9335 - acc: 0.8664 - val_loss: 0.3128 - val_auc: 0.9565 - val_acc: 0.8970
#
# Epoch 00003: val_loss improved from 0.39204 to 0.31283, saving model to first_model.hdf5
# Epoch 4/50
# 119/119 [==============================] - 241s 2s/step - loss: 0.3176 - auc: 0.9508 - acc: 0.8857 - val_loss: 0.2778 - val_auc: 0.9636 - val_acc: 0.9016
#
# Epoch 00004: val_loss improved from 0.31283 to 0.27777, saving model to first_model.hdf5
# Epoch 5/50
# 119/119 [==============================] - 251s 2s/step - loss: 0.2547 - auc: 0.9682 - acc: 0.9099 - val_loss: 0.2224 - val_auc: 0.9764 - val_acc: 0.9240
#
# Epoch 00006: val_loss improved from 0.23802 to 0.22243, saving model to first_model.hdf5
# Epoch 7/50
# 119/119 [==============================] - 258s 2s/step - loss: 0.2434 - auc: 0.9705 - acc: 0.9130 - val_loss: 0.2209 - val_auc: 0.9759 - val_acc: 0.9249
#
# Epoch 00007: val_loss improved from 0.22243 to 0.22093, saving model to first_model.hdf5
# Epoch 8/50
# 119/119 [==============================] - 242s 2s/step - loss: 0.2331 - auc: 0.9727 - acc: 0.9183 - val_loss: 0.2103 - val_auc: 0.9782 - val_acc: 0.9271
#
# Epoch 00008: val_loss improved from 0.22093 to 0.21035, saving model to first_model.hdf5
# Epoch 9/50
# 119/119 [==============================] - 242s 2s/step - loss: 0.2274 - auc: 0.9740 - acc: 0.9213 - val_loss: 0.2072 - val_auc: 0.9786 - val_acc: 0.9278
#
# Epoch 00009: val_loss improved from 0.21035 to 0.20715, saving model to first_model.hdf5
# Epoch 10/50
# 119/119 [==============================] - 240s 2s/step - loss: 0.2242 - auc: 0.9747 - acc: 0.9218 - val_loss: 0.2024 - val_auc: 0.9797 - val_acc: 0.9290
#
# Epoch 00010: val_loss improved from 0.20715 to 0.20240, saving model to first_model.hdf5
# Epoch 11/50
# 119/119 [==============================] - 241s 2s/step - loss: 0.2195 - auc: 0.9758 - acc: 0.9229 - val_loss: 0.2025 - val_auc: 0.9796 - val_acc: 0.9279
#
# Epoch 00011: val_loss did not improve from 0.20240
# Epoch 12/50
# 119/119 [==============================] - 240s 2s/step - loss: 0.2177 - auc: 0.9760 - acc: 0.9233 - val_loss: 0.1984 - val_auc: 0.9804 - val_acc: 0.9306
#
# Epoch 00012: val_loss improved from 0.20240 to 0.19842, saving model to first_model.hdf5
# Epoch 13/50
# 119/119 [==============================] - 244s 2s/step - loss: 0.2155 - auc: 0.9765 - acc: 0.9257 - val_loss: 0.1985 - val_auc: 0.9804 - val_acc: 0.9295
#
# Epoch 00013: val_loss did not improve from 0.19842
# Epoch 14/50
# 119/119 [==============================] - 238s 2s/step - loss: 0.2122 - auc: 0.9774 - acc: 0.9256 - val_loss: 0.1997 - val_auc: 0.9800 - val_acc: 0.9300
#
# Epoch 00014: val_loss did not improve from 0.19842
# Epoch 15/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.2087 - auc: 0.9782 - acc: 0.9268 - val_loss: 0.1919 - val_auc: 0.9819 - val_acc: 0.9327
#
# Epoch 00015: val_loss improved from 0.19842 to 0.19191, saving model to first_model.hdf5
# Epoch 16/50
# 119/119 [==============================] - 237s 2s/step - loss: 0.2057 - auc: 0.9789 - acc: 0.9270 - val_loss: 0.1994 - val_auc: 0.9800 - val_acc: 0.9297
#
# Epoch 00016: val_loss did not improve from 0.19191
# Epoch 17/50
# 119/119 [==============================] - 237s 2s/step - loss: 0.2050 - auc: 0.9789 - acc: 0.9283 - val_loss: 0.1879 - val_auc: 0.9826 - val_acc: 0.9343
#
# Epoch 00017: val_loss improved from 0.19191 to 0.18791, saving model to first_model.hdf5
# Epoch 18/50
# 119/119 [==============================] - 247s 2s/step - loss: 0.2018 - auc: 0.9796 - acc: 0.9298 - val_loss: 0.1898 - val_auc: 0.9822 - val_acc: 0.9327
#
# Epoch 00018: val_loss did not improve from 0.18791
# Epoch 19/50
# 119/119 [==============================] - 255s 2s/step - loss: 0.1997 - auc: 0.9801 - acc: 0.9303 - val_loss: 0.1947 - val_auc: 0.9810 - val_acc: 0.9314
#
# Epoch 00019: val_loss did not improve from 0.18791
# Epoch 20/50
# 119/119 [==============================] - 246s 2s/step - loss: 0.1991 - auc: 0.9802 - acc: 0.9297 - val_loss: 0.1824 - val_auc: 0.9837 - val_acc: 0.9363
#
# Epoch 00020: val_loss improved from 0.18791 to 0.18241, saving model to first_model.hdf5
# Epoch 21/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1954 - auc: 0.9810 - acc: 0.9311 - val_loss: 0.1827 - val_auc: 0.9836 - val_acc: 0.9354
#
# Epoch 00021: val_loss did not improve from 0.18241
# Epoch 22/50
# 119/119 [==============================] - 237s 2s/step - loss: 0.1939 - auc: 0.9812 - acc: 0.9310 - val_loss: 0.1802 - val_auc: 0.9842 - val_acc: 0.9356
#
# Epoch 00022: val_loss improved from 0.18241 to 0.18024, saving model to first_model.hdf5
# Epoch 23/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1927 - auc: 0.9815 - acc: 0.9326 - val_loss: 0.1772 - val_auc: 0.9847 - val_acc: 0.9371
#
# Epoch 00023: val_loss improved from 0.18024 to 0.17718, saving model to first_model.hdf5
# Epoch 24/50
# 119/119 [==============================] - 240s 2s/step - loss: 0.1883 - auc: 0.9824 - acc: 0.9346 - val_loss: 0.1736 - val_auc: 0.9855 - val_acc: 0.9390
#
# Epoch 00024: val_loss improved from 0.17718 to 0.17356, saving model to first_model.hdf5
# Epoch 25/50
# 119/119 [==============================] - 248s 2s/step - loss: 0.1885 - auc: 0.9822 - acc: 0.9348 - val_loss: 0.1728 - val_auc: 0.9856 - val_acc: 0.9397
#
# Epoch 00025: val_loss improved from 0.17356 to 0.17285, saving model to first_model.hdf5
# Epoch 26/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1877 - auc: 0.9825 - acc: 0.9341 - val_loss: 0.1760 - val_auc: 0.9849 - val_acc: 0.9381
#
# Epoch 00026: val_loss did not improve from 0.17285
# Epoch 27/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1869 - auc: 0.9827 - acc: 0.9349 - val_loss: 0.1702 - val_auc: 0.9860 - val_acc: 0.9397
#
# Epoch 00027: val_loss improved from 0.17285 to 0.17022, saving model to first_model.hdf5
# Epoch 28/50
# 119/119 [==============================] - 265s 2s/step - loss: 0.1838 - auc: 0.9832 - acc: 0.9363 - val_loss: 0.1784 - val_auc: 0.9843 - val_acc: 0.9394
#
# Epoch 00028: val_loss did not improve from 0.17022
# Epoch 29/50
# 119/119 [==============================] - 281s 2s/step - loss: 0.1822 - auc: 0.9836 - acc: 0.9380 - val_loss: 0.1710 - val_auc: 0.9858 - val_acc: 0.9419
#
# Epoch 00029: val_loss did not improve from 0.17022
# Epoch 30/50
# 119/119 [==============================] - 271s 2s/step - loss: 0.1796 - auc: 0.9841 - acc: 0.9382 - val_loss: 0.1680 - val_auc: 0.9863 - val_acc: 0.9429
#
# Epoch 00030: val_loss improved from 0.17022 to 0.16795, saving model to first_model.hdf5
# Epoch 31/50
# 119/119 [==============================] - 248s 2s/step - loss: 0.1806 - auc: 0.9838 - acc: 0.9392 - val_loss: 0.1712 - val_auc: 0.9857 - val_acc: 0.9413
#
# Epoch 00031: val_loss did not improve from 0.16795
# Epoch 32/50
# 119/119 [==============================] - 249s 2s/step - loss: 0.1785 - auc: 0.9842 - acc: 0.9401 - val_loss: 0.1684 - val_auc: 0.9862 - val_acc: 0.9430
#
# Epoch 00032: val_loss did not improve from 0.16795
# Epoch 33/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1767 - auc: 0.9846 - acc: 0.9393 - val_loss: 0.1650 - val_auc: 0.9869 - val_acc: 0.9452
#
# Epoch 00033: val_loss improved from 0.16795 to 0.16496, saving model to first_model.hdf5
# Epoch 34/50
# 119/119 [==============================] - 248s 2s/step - loss: 0.1749 - auc: 0.9850 - acc: 0.9413 - val_loss: 0.1639 - val_auc: 0.9870 - val_acc: 0.9451
#
# Epoch 00034: val_loss improved from 0.16496 to 0.16387, saving model to first_model.hdf5
# Epoch 35/50
# 119/119 [==============================] - 240s 2s/step - loss: 0.1730 - auc: 0.9853 - acc: 0.9409 - val_loss: 0.1647 - val_auc: 0.9868 - val_acc: 0.9457
#
# Epoch 00035: val_loss did not improve from 0.16387
# Epoch 36/50
# 119/119 [==============================] - 241s 2s/step - loss: 0.1719 - auc: 0.9853 - acc: 0.9416 - val_loss: 0.1630 - val_auc: 0.9871 - val_acc: 0.9460
#
# Epoch 00036: val_loss improved from 0.16387 to 0.16304, saving model to first_model.hdf5
# Epoch 37/50
# 119/119 [==============================] - 261s 2s/step - loss: 0.1719 - auc: 0.9855 - acc: 0.9418 - val_loss: 0.1699 - val_auc: 0.9857 - val_acc: 0.9437
#
# Epoch 00037: val_loss did not improve from 0.16304
# Epoch 38/50
# 119/119 [==============================] - 242s 2s/step - loss: 0.1698 - auc: 0.9857 - acc: 0.9432 - val_loss: 0.1622 - val_auc: 0.9872 - val_acc: 0.9470
#
# Epoch 00038: val_loss improved from 0.16304 to 0.16218, saving model to first_model.hdf5
# Epoch 39/50
# 119/119 [==============================] - 248s 2s/step - loss: 0.1675 - auc: 0.9862 - acc: 0.9434 - val_loss: 0.1579 - val_auc: 0.9880 - val_acc: 0.9467
#
# Epoch 00039: val_loss improved from 0.16218 to 0.15794, saving model to first_model.hdf5
# Epoch 40/50
# 119/119 [==============================] - 254s 2s/step - loss: 0.1670 - auc: 0.9864 - acc: 0.9432 - val_loss: 0.1572 - val_auc: 0.9882 - val_acc: 0.9460
#
# Epoch 00040: val_loss improved from 0.15794 to 0.15724, saving model to first_model.hdf5
# Epoch 41/50
# 119/119 [==============================] - 238s 2s/step - loss: 0.1653 - auc: 0.9865 - acc: 0.9440 - val_loss: 0.1563 - val_auc: 0.9883 - val_acc: 0.9471
#
# Epoch 00041: val_loss improved from 0.15724 to 0.15627, saving model to first_model.hdf5
# Epoch 42/50
# 119/119 [==============================] - 242s 2s/step - loss: 0.1651 - auc: 0.9866 - acc: 0.9450 - val_loss: 0.1582 - val_auc: 0.9878 - val_acc: 0.9483
#
# Epoch 00042: val_loss did not improve from 0.15627
# Epoch 43/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1631 - auc: 0.9870 - acc: 0.9455 - val_loss: 0.1564 - val_auc: 0.9882 - val_acc: 0.9470
#
# Epoch 00043: val_loss did not improve from 0.15627
# Epoch 44/50
# 119/119 [==============================] - 235s 2s/step - loss: 0.1629 - auc: 0.9870 - acc: 0.9449 - val_loss: 0.1574 - val_auc: 0.9879 - val_acc: 0.9486
#
# Epoch 00044: val_loss did not improve from 0.15627
# Epoch 45/50
# 119/119 [==============================] - 264s 2s/step - loss: 0.1613 - auc: 0.9873 - acc: 0.9469 - val_loss: 0.1575 - val_auc: 0.9879 - val_acc: 0.9490
#
# Epoch 00045: val_loss did not improve from 0.15627
# Epoch 46/50
# 119/119 [==============================] - 241s 2s/step - loss: 0.1603 - auc: 0.9873 - acc: 0.9468 - val_loss: 0.1562 - val_auc: 0.9881 - val_acc: 0.9484
#
# Epoch 00046: val_loss improved from 0.15627 to 0.15616, saving model to first_model.hdf5
# Epoch 47/50
# 119/119 [==============================] - 239s 2s/step - loss: 0.1591 - auc: 0.9876 - acc: 0.9467 - val_loss: 0.1535 - val_auc: 0.9886 - val_acc: 0.9483
#
# Epoch 00047: val_loss improved from 0.15616 to 0.15348, saving model to first_model.hdf5
# Epoch 48/50
# 119/119 [==============================] - 237s 2s/step - loss: 0.1581 - auc: 0.9878 - acc: 0.9473 - val_loss: 0.1571 - val_auc: 0.9879 - val_acc: 0.9490
#
# Epoch 00048: val_loss did not improve from 0.15348
# Epoch 49/50
# 119/119 [==============================] - 237s 2s/step - loss: 0.1576 - auc: 0.9879 - acc: 0.9464 - val_loss: 0.1574 - val_auc: 0.9878 - val_acc: 0.9484
#
# Epoch 00049: val_loss did not improve from 0.15348
# Epoch 50/50
# 119/119 [==============================] - 236s 2s/step - loss: 0.1568 - auc: 0.9881 - acc: 0.9473 - val_loss: 0.1515 - val_auc: 0.9890 - val_acc: 0.9490
#
# Epoch 00050: val_loss improved from 0.15348 to 0.15153, saving model to first_model.hdf5

# %%
# add history of accuracy and validation accuracy to the plot
plt.plot(history.history['acc'], label = 'train',)
plt.plot(history.history['val_acc'], label = 'valid')

# adding legend and labels
plt.legend(loc = 'lower right')
plt.xlabel('epochs')
plt.ylabel('accuracy')

# show the plot
plt.show()

# %%
# see if it's good at predecting new inputs
result = first_model.evaluate(test_generator)
# Out:
# 25/25 [==============================] - 79s 3s/step - loss: 0.1412 - auc: 0.9904 - acc: 0.9565
